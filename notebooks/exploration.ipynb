# %% [markdown]
# # Stock Advisor — 数据探索
#
# 用于探索股票数据、测试技术指标、验证策略的 Notebook。

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import akshare as ak

# %matplotlib inline
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False

# %%
# 测试获取数据
# df = ak.stock_zh_a_hist(symbol="000001", period="daily", start_date="20240101", end_date="20250630", adjust="qfq")
# df.head()
